# %%
import numpy as np
import pandas as  pd

# %%
df=pd.read_csv("dataset_Facebook.csv",delimiter=';')

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
cols=dataset[0:5]
print(cols.head())
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
index=df.index
print("Index is ",str(index))
# Out:
# Index is  RangeIndex(start=0, stop=500, step=1)

# %%
cols=df.columns

# %%
print(dataset.iloc[3:5])
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 3                    2211                      790
# 4                     671                      410
#
#    Lifetime Post Consumptions  \
# 3                        1119
# 4                         580
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 3                                              61027
# 4                                               6228
#
#    Lifetime Post reach by people who like your Page  \
# ...

# %%
print(dataset.iloc[:5])
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
print(dataset.loc[[2, 4, 5], ['Type', 'Category']])
# Out:
#      Type  Category
# 2   Photo         3
# 4   Photo         2
# 5  Status         2

# %%
print('no of cols'+str(len(dataset.columns)))
# Out:
# no of cols19

# %%
dataset['Type'] 
video_sub=dataset['Type'] 
print(dataset.columns)
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
Bydf_subset = dataset[['like','share']] 
print(Bydf_subset)
# Out:
#        like  share
# 0      79.0   17.0
# 1     130.0   29.0
# 2      66.0   14.0
# 3    1572.0  147.0
# 4     325.0   49.0
# ..      ...    ...
# 495    53.0   26.0
# 496    53.0   22.0
# 497    93.0   18.0
# 498    91.0   38.0
# 499    91.0   28.0
#
# [500 rows x 2 columns]

# %%
Hydf_subset1 = dataset[dataset['like']>100] 
print(Hydf_subset1)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 488             85979   Photo         3           1             7         10
# 491             85979   Photo         3           1             6          3
# 492             85979    Link         1           1             5         11
# 493             85093   Photo         3           1             1          2
# 494             85093   Photo         3           1             7         10
#
# ...

# %%
dataset.loc[1:7,['like','share']]
# Out:
#      like  share
# 1   130.0   29.0
# 2    66.0   14.0
# 3  1572.0  147.0
# 4   325.0   49.0
# 5   152.0   33.0
# 6   249.0   27.0
# 7   325.0   14.0

# %%
dataset.sort_values(by = "like",ascending= False)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 21             138414  Photo         1          12             7         10
# 100            137020  Photo         1          10             4          9
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
dataset.sort_values("like")
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 417            104070  Photo         1           3             3         10
# 100            137020  Photo         1          10             4          9
# 76             137893  Photo         1          11             3          2
# 441             98195  Photo         1           3             5          4
# ..                ...    ...       ...         ...           ...        ...
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
dataset.sort_values(by = "like",ascending= False, kind="mergesort")
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 76             137893  Photo         1          11             3          2
# 100            137020  Photo         1          10             4          9
# 417            104070  Photo         1           3             3         10
# 441             98195  Photo         1           3             5          4
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
Byresult = dataset.transpose() 
print(Byresult)
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
selective_df = pd.DataFrame(dataset,columns =['like','share','Category','Type']) 
print(selective_df.head(5))
# Out:
#      like  share  Category    Type
# 0    79.0   17.0         2   Photo
# 1   130.0   29.0         2  Status
# 2    66.0   14.0         3   Photo
# 3  1572.0  147.0         2   Photo
# 4   325.0   49.0         2   Photo

# %%
pivot_table = pd.pivot_table(selective_df,index= ['Category','like']) 
print(pivot_table)
# Out:
#                       share
# Category like
# 1        0.0       0.000000
#          1.0       2.000000
#          2.0       0.000000
#          3.0       0.666667
#          4.0       1.000000
# ...                     ...
# 3        1155.0  102.000000
#          1372.0   47.000000
#          1546.0  181.000000
#          1639.0  122.000000
#          1998.0  128.000000
#
# [368 rows x 1 columns]

# %%
ldataset = dataset.iloc[:,0:10]
ldataset[['Paid','Category']]
print(ldataset.loc[[2,3,4],['Paid','Category']])
# Out:
#    Paid  Category
# 2   0.0         3
# 3   1.0         2
# 4   0.0         2

# %%
rdataset = dataset.iloc[:,9:20]   
print(rdataset.head())
# Out:
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 1                    1457                     1361
# 2                     177                      113
# 3                    2211                      790
# 4                     671                      410
#
#    Lifetime Post Consumptions  \
# 0                         159
# 1                        1674
# 2                         154
# 3                        1119
# 4                         580
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                               3078
# 1                                              11710
# 2                                               2812
# 3                                              61027
# 4                                               6228
#
#    Lifetime Post reach by people who like your Page  \
# 0                                              1640
# ...

# %%
rdataset = dataset.iloc[:,9:20]   
print(rdataset.head())
# Out:
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 1                    1457                     1361
# 2                     177                      113
# 3                    2211                      790
# 4                     671                      410
#
#    Lifetime Post Consumptions  \
# 0                         159
# 1                        1674
# 2                         154
# 3                        1119
# 4                         580
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                               3078
# 1                                              11710
# 2                                               2812
# 3                                              61027
# 4                                               6228
#
#    Lifetime Post reach by people who like your Page  \
# 0                                              1640
# ...

# %%
common_values = ldataset['Lifetime Engaged Users'].isin(rdataset['Lifetime Engaged Users']).value_counts()
print (common_values)
# Out:
# True    500
# Name: Lifetime Engaged Users, dtype: int64

# %%
leftjoin =  pd.merge(ldataset,rdataset[['Lifetime Engaged Users','Lifetime Post Consumers']],on='Lifetime Engaged Users',how='left')
print ("Left join")
print(leftjoin.head())
# Out:
# Left join
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# ...

# %%
rightjoin =  pd.merge(ldataset,rdataset[['Lifetime Engaged Users','Lifetime Post Consumers']],on='Lifetime Engaged Users',how='right')
# merge right join
print(rightjoin.head())
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# 0                     178                      109
# ...

# %%
outerjoin =  pd.merge(ldataset,rdataset[['Lifetime Engaged Users','Lifetime Post Consumers']],on='Lifetime Engaged Users',how='outer')
print(outerjoin.head())
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# 0                     178                      109
# ...

# %%
innerjoin =  pd.merge(ldataset,rdataset[['Lifetime Engaged Users','Lifetime Post Consumers']],on='Lifetime Engaged Users',how='inner')
print(innerjoin.head())
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# 0                     178                      109
# ...

# %%
sorted_data = dataset.sort_values('Lifetime Post Total Reach') 
print(sorted_data.head(n=3))
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 422            102112  Photo         1           3             1         19
# 426            100732  Photo         1           3             7         18
# 432            100732  Photo         1           3             6         17
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 422   0.0                        238                              570
# 426   0.0                        391                              746
# 432   0.0                        452                              726
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 422                     143                      142
# 426                     131                      130
# 432                     186                      184
#
#      Lifetime Post Consumptions  \
# 422                         834
# 426                         766
# 432                         889
#
# ...

# %%
desc_sorted_data = dataset.sort_values('Lifetime Post Total Reach',ascending=False) 
print(desc_sorted_data.head(n=3))
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 464             92079  Photo         1           2             6         13
# 463             92186  Photo         3           2             7          2
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
# 464   0.0                     158208                           453213
# 463   1.0                     153536                           497910
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 244                    8072                     4010
# 464                    2482                     2319
# 463                    1713                     1633
#
#      Lifetime Post Consumptions  \
# 244                        6242
# 464                        3412
# 463                        2493
#
# ...

# %%
dataset.sort_values('Lifetime Post Total Reach',inplace=True,ascending=False) 
dataset.sort_index(inplace=True)

# %%
trans_data = dataset.T
print(trans_data.head())
# Out:
#                      0       1       2       3       4       5       6    \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo  Status   Photo
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                      7       8       9    ...    490    491    492    493  \
# Page total likes  139441  139441  139441  ...  85979  85979  85979  85093
# Type               Photo  Status   Photo  ...  Photo  Photo   Link  Photo
# Category               3       2       3  ...      3      3      1      3
# Post Month            12      12      12  ...      1      1      1      1
# Post Weekday           7       7       6  ...      6      6      5      1
#
#                     494    495    496    497    498    499
# ...

# %%
df = pd.DataFrame({'Name': {0: 'Shubham', 1: 'Prsika', 2: 'Ishwar'}, 
                   'Course': {0:'12th', 1: '12th', 2: 'Diploma'}, 
                   'Roll No': {0: 1, 1: 2, 2: 3}})
print(df)
# Out:
#       Name   Course  Roll No
# 0  Shubham     12th        1
# 1   Prsika     12th        2
# 2   Ishwar  Diploma        3

# %%
pd.melt(df, id_vars =['Name'], value_vars =['Course'])
pd.melt(df, id_vars =['Name'], value_vars =['Course', 'Roll No'])
# Out:
#       Name variable    value
# 0  Shubham   Course     12th
# 1   Prsika   Course     12th
# 2   Ishwar   Course  Diploma
# 3  Shubham  Roll No        1
# 4   Prsika  Roll No        2
# 5   Ishwar  Roll No        3

# %%
meltdata1 = pd.melt(dataset,id_vars = ['Type'], value_vars = ['Post Hour'])
print(meltdata1.head(n=10))
# Out:
#      Type   variable  value
# 0   Photo  Post Hour      3
# 1  Status  Post Hour     10
# 2   Photo  Post Hour      3
# 3   Photo  Post Hour     10
# 4   Photo  Post Hour      3
# 5  Status  Post Hour      9
# 6   Photo  Post Hour      3
# 7   Photo  Post Hour      9
# 8  Status  Post Hour      3
# 9   Photo  Post Hour     10
